# %% [markdown]
# Summarizing and Visualizing of Data
# 1. Numerical based data
#
# For Numerical we consider the following 3 points:
#
# i. Center : Mean or Median or Mode
# ii. Shape: Skewed or Bell-shaped
# iii.Range or IQR or Variance
#
# 2. Categorical based Data
# For categorical data we consider the follwing:
# i.Propotion or Count or Mode

# %% [markdown]
# **Measures of central Tendency**
#
# i. Mean -- Average of a data
# ii. Median -- Cetral value of the ordered data
# iii. Mode --value that occurs most often in the data

# %% [markdown]
# Mean-

# %%
data=[2,4,6,8,1,7,4]
mean=2+4+6+8+1+7+4/7
print(mean)
# Out:
# 28.571428571428573

# %% [markdown]
# Median-

# %%
data=[2,4,6,8,1,7,4,10]
data.sort()

# %%
data
# Out:
# [1, 2, 4, 4, 6, 7, 8, 10]

# %%
median=(4+6)/2
print(median)
# Out:
# 5.0

# %% [markdown]
# Mode-

# %%
data=[2,4,6,8,1,7,4]

# %%
mode=4

# %% [markdown]
# Mode can be used both for Numerical and Categorical data

# %% [markdown]
# Example:

# %%
salaries=[28000,34000,33000,37000,33000,40000,40000]

# %%
salaries.sort()

# %%
salaries
# Out:
# [28000, 33000, 33000, 34000, 37000, 40000, 40000]

# %%
sal_median=(330000+340000)/2

# %%
sal_median
# Out:
# 335000.0
