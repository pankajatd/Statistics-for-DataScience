# %% [markdown]
# Confident Interval:
#
# We try to find the Upper and Lower values between which we can be Confident the Population Mean falls.
#
# An Interval of such values is referred to as Confidence Interval
