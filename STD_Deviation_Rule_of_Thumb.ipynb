# %% [markdown]
# 1. When the data lies between the range **(mu+sigma and mu-sigma)**, it contains **68% **of the Data
#
# 2. when the data  lies between the range **( mu+2*sigma and mu +2*sigma)** ,it contans **95%** of the data
#
# 3. when the data lies in the range **(mu+3*sigma and mu-3*sigma) ** ,it contains **99.7% **of the data

# %% [markdown]
# Data is said to be an Outlier if it lies in the range beyond (mu-4*sigma) and (mu+4*sigma)

# %% [markdown]
# Interview Question1:
# Q:mu=1500,sigma=300,Curve =Normal Curve and Spread is givem as 900 to 2100 ..
# What is the percentage this data is spread
#
# Ans: 1. For 68% range we have (mu-sigma),(mu+sigma)
#                      (1500 -300),(1500+300)
#                       (1200)(1800)
# Conclusion: So it is not the 68% range
#
# 2. For 95% range we have(mu-2*sigma)(mu+2*sigma)
#                         (1500-2*300)(1500+2*300)
#                         (900)(2100)
#   Conclusion : This matches the given range .. hence the data lies in then the 95% range
#
#
#
# Interview Question2:
# Q:mu=1500,sigma=300,Curve =Normal Curve and Spread is givem as 1500 to 2100 ..
# What is the percentage this data is spread?
#
# Ans : For (mu-2*sigma)(mu+2*sigma) we have the range 900 and 2100
#
# So now for the range 1500 to 2100 ⁉we have mu =1500 ,this means it lies on the right hand side of mu+2*sigma .There it lies in 95%/2 =47.5%
#
# Interview Question3:If z>3 what do we say about the Data?
#
# Ans: 1. For the range (mu-3*sigma) and (mu+3*sigma) then z=3.
#      2. For the range (mu-2*sigma) and (mu+2*sigma) then z=2.
#      3. For the range (mu-sigma) and (mu+sigma) then z=1.
# for z>3 ,we say that there is high chance of outliers.
