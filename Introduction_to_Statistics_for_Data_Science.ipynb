# %% [markdown]
# What is statistics?
#
# A. Statistics is the Science of Learning from Data

# %% [markdown]
# Steps to learn from the Data
#
# 1. Define the Problem Statement
# Ex: To identify if a person is Diabetic or Non-Diabetic
#
# 2. Collecting the relevant Data
#
# 3.Si=ummarizing the Data
# Ex:Mean ,Meadian,mode,Skewnees, Kurtosis etc.
#
# 4. Analyizing teh Data,Interpreting the Data and Communicating the results.
