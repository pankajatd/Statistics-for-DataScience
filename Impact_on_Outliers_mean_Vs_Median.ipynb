# %%
salaries=[28000,34000,33000,37000,33000,40000,40000]

# %% [markdown]
# Calculate the Mean

# %%
sal_mean=(28000+34000+33000+37000+33000+40000+40000)/7

# %%
sal_mean
# Out:
# 35000.0

# %% [markdown]
# Calculate the Median

# %%
#sort the salaries
sorted_salaries= 28000,33000,33000,34000,37000,40000,40000

# %%
sal_median=34000

# %% [markdown]
# If there is an Outlier ,which Central Tendency to consider

# %%
salaries=[28000,34000,33000,37000,33000,40000,400000]

# %%
mean_sal=(28000+34000+33000+37000+33000+40000+400000)/7

# %%
mean_sal
# Out:
# 86428.57142857143

# %% [markdown]
# Calculating the Median with Outlier

# %%
salaries=[28000,34000,33000,37000,33000,40000,400000]

# %%
#sort the salaries
sorted_salaries= 28000,33000,33000,34000,37000,40000,40000

# %%
sal_median =34000

# %% [markdown]
# We can conclude that ,with Outlier in the Data ,Mean is impacted a lot .
#
# Hence Median is considered as the better Option when there exists an Outlier.
#
# Mean or Median can be considered if there is no Outlier. Both giv ethe same result.
