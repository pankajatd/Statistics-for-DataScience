# %% [markdown]
# P-Value

# %% [markdown]
# Example: The product which has a mean height of mu(mean)=20 and
#
# sigma(Std Deviation)=4..After the Inspection it was obeserved that Product Mean >20.
# Ans :1. Determine the Null Hypothesis and Alternate Hypothesis
#        Null hupothesis  -- mean =20
#
#        Alternate hypothesis ---mean!=20
#
#     2. Determine the Sample Statistics that is teh Sample mean
#
#     3. Calculate the Probability value or the P-value: P-Value gives the Probability for the Null Hypotthesis to be True.
#
#     If P-value > alpha(Significance Value)  the we Fail to Reject the Null Hypothesis
#
#     If P-value < alpha(Significance Value)  the we Reject the Null Hypothesis
#
# We calculate the Probability(X_bar >=22,mu =20) =P(z>>(22-20)/4/sqrt(36))
#                                                 =P(z>(2)/4/6) =P(z>=3)
#
# 1-P(z<3) ==Looking at the Z table we get the value as 0.9987
#
# 1-0.9987 =0.0013
#
# We know value of Alpha  =0.05
#
# If P-value < 0.05 we Reject the Null Hypothesis
#
#
#
#
# **Note- 1. P-Value is the Probability of Accepting or Rejecting the Null Hypothesis**
#
#        2. If P<=Alpha.. we Reject teh Null Hypothesis
#
#
#   Conclusion :We Reject the Nul hypothesis that the Mean =20
#
#
#   Steps for Rjecting the Null Hypothesis and Fail to Reject the Null Hypothesis
#
#   1.Check the necessary condition(in the above example the Condition : mu=20 or mu>20)  to run the selected Test and Hypothesis for the Test
#
#   2.Decide on the Significance level Alpha
#
#   3.Compute the Test statistic value i.e X_bar
#
#   4.Compute the P-Value
#
#   5.Check if P<alpha. if P<alpha Reject the NUll Hypothesis or Fail to Reject the Null Hypothesis
#
#   6.State the conclsion in words.
