# %% [markdown]
# Population Variance(Sigma**2) = 1/N(summation(xi-mu)**2  where i ranges from 1 to N
#
# Here mu is the Population Mean
#
#
# Here we are trying to see the variance that is.. how far is the data point from the population mean

# %% [markdown]
# Sample Variance(S**2) =1/(n-1)(summation(xi-x_bar)**2 where n ranges from 1 to n
#
# Here x_bar is Sample Mean
#
# Here we are trying to see the variance that is.. how far is the data point from the Sample mean

# %% [markdown]
# Sample is the Subset of the whole Population data
#
# The sample n << population N

# %% [markdown]
# Population Std Deviation(Sigma) = SQRT(1/N(summation(xi-mu)**2) where i ranges from 1 to N

# %% [markdown]
# Sample Std Deviation(S) =SQRT(1/(n-1)(summation(xi-x_bar)**2) where n ranges from 1 to n

# %% [markdown]
# Interview Question:
#
# In Sample variance why we divide the Denominator by (n-1) instead of n ??
#
# Ans:
