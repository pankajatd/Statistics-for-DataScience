# %% [markdown]
# **Descriptive Statistics**
#
# **1. Mean,median,Mode,Max,minima,Percentile(50%,70%)**
#
# **2.Measure the Dispersion of the Data:**
#
#   i. **Range **- Range relies on the Maximum and the Minimum value.When there are Outliers " range " is not the best method to use.
#
#   ii.** IQR -** For detecting teh Outliers this is one of teh Best method.
#
#   iii.**Standard Deviation and Variance** - This tells us how much is the Spread of the Data ,while plotting the Distribution of the Data.
#
#   iv. **Central Limit Theorem**
#
#   **v. Normal Distribution **
#
#   vi.** Probability Distribution**
#
#   vii. **Correlation** - ranges from +1 to -1
#
#   viii. **Hypothesis Testing -** Understanding of P-Value,impact of P-value
