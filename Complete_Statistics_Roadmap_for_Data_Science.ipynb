# %% [markdown]
# Statistics for Data Science
#
# Understaanding of Population Data and Sample Data
# Understanding of Random Variables
# Understanding of CDF and PDF
# Understanding
#
# **1> Descriptive Statistics **--We do the summarizing
#
# i. Data
#
# ii.Analysis of the Data
#
# iii. Visualization of the Data
#
# a. It is a Measure of Central Tendency
#
#    i.  Mean
#
#    ii. Median
#
#    iii.Mode
#
# b. Measure of Dispersion
#
#    i.  Range
#
#    ii. IQR (Inter Quartile Range)
#
#    iii.Standard Deviation & Variance
#
# c. Outliers
#    i. Box Plot -IQR, Lower and Upper Whisker
#
# d. Visualization of the Data
#
#    i.Histogram
#
#    ii. Bar Graph
#
#    iii. Scatter plot.
#
# e. Normal Distribution or a Gaussian Distrubituion
#
#   i. Understanding of Central Limit Thoerem and real time Application of Central Limit Theorem
#
#   ii. Skewed Distribution and Non-Skewed Distribution
#
#   iii. Posion Distribution
#
#   iv. Binomial /Bernoulli distribution
#
# **2.Infrenetial Statistics-**
#
# Hypothesis Testing is a part of Infrential Statistics -
#
# Hypothesis Testing involves -
#
# a. Null Hypothesis
#
# b. Alternate Hypothesis
#
# c. Type I and Type II error
#
# d. P-Value
#
# e. Correlation Coefficient
#
# f.Covariance
#
# g.Confidence Interval
#
# h. Z-Score
#
# i. Standard Normalization
#
#   Z-test,T-Test,Annova-Test
#
# j. Log Normal Distribution
#
# k.Uni-Variate,Bi-variate,Multi-Variate
